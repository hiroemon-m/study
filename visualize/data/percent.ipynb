# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cbook as cbook
import japanize_matplotlib

# %%
attr_auc_baseline = []
attr_nll_baseline = []
edge_auc_baseline = []
edge_nll_baseline = []




attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_attr_auc.npy"
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_attr_nll.npy"
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_edge_auc.npy"
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/NIPS/64_5/persona = 32/proposed_edge_nll.npy"

attr_auc_baseline.append(np.load(attr_auc_path))
attr_nll_baseline.append(np.load(attr_nll_path))
edge_auc_baseline.append(np.load(edge_auc_path))
edge_nll_baseline.append(np.load(edge_nll_path))


attr_mean_baseline = np.mean(attr_auc_baseline,axis=1)
attr_max_baseline = np.max(attr_auc_baseline,axis=1)
attr_min_baseline = np.min(attr_auc_baseline,axis=1)

attr_mean_nll_baseline = np.mean(attr_nll_baseline,axis=1)
attr_max_nll_baseline = np.max(attr_nll_baseline,axis=1)
attr_min_nll_baseline = np.min(attr_nll_baseline,axis=1)

edge_mean_baseline = np.mean(edge_auc_baseline,axis=1)
edge_max_baseline = np.max(edge_auc_baseline,axis=1)
edge_min_baseline = np.min(edge_auc_baseline,axis=1)

edge_mean_nll_baseline = np.mean(edge_nll_baseline,axis=1)
edge_max_nll_baseline = np.max(edge_nll_baseline,axis=1)
edge_min_nll_baseline = np.min(edge_nll_baseline,axis=1)

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
   
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(15):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/NIPS/incomplete/t=4/edge/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))

  


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))

plist=[5,15,30,50,75]
t = [1,2,3,4,5]
colorli = ['maroon','gold','darkgreen','purple','red']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k])+"%欠損", color=colorli[k])
    axes[0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k])+"%欠損", color=colorli[k])
    axes[1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション




        #キャプション

   

    axes[0].set_xticks([1,2,3,4,5])  
    axes[1].set_xticks([1,2,3,4,5])    
 
axes[0].plot(t, edge_mean_baseline[0][:], lw=2, label='欠損なし', color='blue')
axes[0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1].plot(t, attr_mean_baseline[0][:], lw=2, label='欠損なし', color='blue')
axes[1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0].set_xlabel('将来の時刻',fontsize=30)
axes[0].set_ylabel('auc',fontsize=30)

axes[1].set_xlabel('将来の時刻',fontsize=30)
axes[1].set_ylabel('auc',fontsize=30)

axes[1].legend(loc='upper left',fontsize=30,bbox_to_anchor=(1, 1))
axes[0].tick_params(axis="x", labelsize=30)
axes[0].tick_params(axis="y", labelsize=30)
axes[1].tick_params(axis="x", labelsize=30)
axes[1].tick_params(axis="y", labelsize=30)
# Out:
# [[array([0.94211118, 0.94588813, 0.9525376 , 0.95565005, 0.84016575]), array([0.9419067 , 0.94366211, 0.94979675, 0.95350881, 0.83538499]), array([0.94268257, 0.94980846, 0.95560976, 0.95821429, 0.84670357])], [array([0.94220008, 0.94615273, 0.95313592, 0.95578309, 0.8406378 ]), array([0.94180972, 0.94201581, 0.95015498, 0.9534833 , 0.83118387]), array([0.94265833, 0.94902531, 0.95722815, 0.9579128 , 0.84396061])], [array([0.94225342, 0.94555628, 0.95264905, 0.95534818, 0.84067877]), array([0.94168849, 0.94103627, 0.94961382, 0.95217764, 0.83637192]), array([0.94317961, 0.94913684, 0.95757876, 0.9605821 , 0.84643683])], [array([0.9420449 , 0.94625618, 0.95234112, 0.95506192, 0.84098337]), array([0.94147027, 0.94395306, 0.94929624, 0.95331633, 0.83654086]), array([0.9426462 , 0.94999758, 0.95504827, 0.9569179 , 0.84536432])], [array([0.94212896, 0.9465123 , 0.9530426 , 0.95624629, 0.83967502]), array([0.94173698, 0.94267287, 0.95003303, 0.95394017, 0.83502823]), array([0.94297352, 0.95072253, 0.95678989, 0.95835575, 0.84618343])]]
# [282.58218587 282.05682434 267.93811951 295.00930013 309.75057129]
# [[array([0.94211118, 0.94588813, 0.9525376 , 0.95565005, 0.84016575]), array([0.9419067 , 0.94366211, 0.94979675, 0.95350881, 0.83538499]), array([0.94268257, 0.94980846, 0.95560976, 0.95821429, 0.84670357])], [array([0.94220008, 0.94615273, 0.95313592, 0.95578309, 0.8406378 ]), array([0.94180972, 0.94201581, 0.95015498, 0.9534833 , 0.83118387]), array([0.94265833, 0.94902531, 0.95722815, 0.9579128 , 0.84396061])], [array([0.94225342, 0.94555628, 0
# [282.82309977 282.2369338  267.85021606 295.05206645 309.77236715]
# [[array([0.92697039, 0.9367664 , 0.94627337, 0.94389904, 0.83450379]), array([0.90439822, 0.91175929, 0.90651677, 0.91157004, 0.78711656]), array([0.9366817 , 0.9510353 , 0.9597815 , 0.96083256, 0.85634947])], [array([0.88108816, 0.89980183, 0.93107275, 0.9106553 , 0.84340676]), array([0.83649743, 0.84898409, 0.87293699, 0.84253942, 0.80094025]), array([0.91801232, 0.92781738, 0.96315295, 0.96343692, 0.87975349])], [array([0.85045017, 0.86424708, 0.85885247, 0.83452396, 0.78753801]), array([0.80646882, 0.83371763, 0.8028811 , 0.75952226, 0.75485018]), array([0.87296334, 0.93346911, 0.90458079, 0.87935065, 0.83763448])], [array([0.78127   , 0.86510296, 0.77146528, 0.75694303, 0.72275555]), array([0.73404616, 0.81616478, 0.74731453, 0.71262639, 0.68042811]), array([0.82574435, 0.89903501, 0.79799543, 0.78305659, 0.81113408])], [array([0.82582436, 0.85208944, 0.87160476, 0.86603942, 0.79859229]), array([0.62275725, 0.68634953, 0.69020579, 0.67365492, 0.67686939]), array([0.943119  , 0.94900107, 0.9560874 , 0.95797078, 0.84632346])]]
# [282.82309977 282.2369338  267.85021606 295.05206645 309.77236715]

# %%
attr_auc_baseline = []
attr_nll_baseline = []
edge_auc_baseline = []
edge_nll_baseline = []




attr_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_attr_auc.npy"
attr_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_attr_nll.npy"
edge_auc_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_edge_auc.npy"
edge_nll_path = "//Users/matsumoto-hirotomo/coma/experiment_data/DBLP/64_5/persona = 32/proposed_edge_nll.npy"

attr_auc_baseline.append(np.load(attr_auc_path))
attr_nll_baseline.append(np.load(attr_nll_path))
edge_auc_baseline.append(np.load(edge_auc_path))
edge_nll_baseline.append(np.load(edge_nll_path))


attr_mean_baseline = np.mean(attr_auc_baseline,axis=1)
attr_max_baseline = np.max(attr_auc_baseline,axis=1)
attr_min_baseline = np.min(attr_auc_baseline,axis=1)

attr_mean_nll_baseline = np.mean(attr_nll_baseline,axis=1)
attr_max_nll_baseline = np.max(attr_nll_baseline,axis=1)
attr_min_nll_baseline = np.min(attr_nll_baseline,axis=1)

edge_mean_baseline = np.mean(edge_auc_baseline,axis=1)
edge_max_baseline = np.max(edge_auc_baseline,axis=1)
edge_min_baseline = np.min(edge_auc_baseline,axis=1)

edge_mean_nll_baseline = np.mean(edge_nll_baseline,axis=1)
edge_max_nll_baseline = np.max(edge_nll_baseline,axis=1)
edge_min_nll_baseline = np.min(edge_nll_baseline,axis=1)

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
   
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(15):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/DBLP/incomplete/t=4/attr/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))


t = [1,2,3,4,5]
colorli = ['maroon','gold','darkgreen','purple','red']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k])+"%欠損", color=colorli[k])
    axes[0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k])+"%欠損", color=colorli[k])
    axes[1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション




        #キャプション

   

    axes[0].set_xticks([1,2,3,4,5])  
    axes[1].set_xticks([1,2,3,4,5])    
 
axes[0].plot(t, edge_mean_baseline[0][:], lw=2, label='欠損なし', color='blue')
axes[0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1].plot(t, attr_mean_baseline[0][:], lw=2, label='欠損なし', color='blue')
axes[1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0].set_xlabel('将来の時刻',fontsize=30)
axes[0].set_ylabel('auc',fontsize=30)

axes[1].set_xlabel('将来の時刻',fontsize=30)
axes[1].set_ylabel('auc',fontsize=30)

axes[1].legend(loc='upper left',fontsize=30,bbox_to_anchor=(1, 1))
axes[0].tick_params(axis="x", labelsize=30)
axes[0].tick_params(axis="y", labelsize=30)
axes[1].tick_params(axis="x", labelsize=30)
axes[1].tick_params(axis="y", labelsize=30)
# Out:
# [[array([0
# [13804.38821615 13880.08290365 14000.12188802 13356.31839844
#  12415.11985677]
# [[array([0.84212417, 0.81461746, 0.8084789 , 0.8075982 , 0.82086414]), array([0.83182733, 0.80315564, 0.79249626, 0.79179912, 0.81262324]), array([0.85791902, 0.82817479, 0.82313583, 0.81910474, 0.83090037])], [array([0.78160944, 0.77302748, 0.77415234, 0.77637646, 0.79442757]), array([0.76780434, 0.76074693, 0.75737701, 0.76026006, 0.77905661]), array([0.79143622, 0.78514862, 0.7892385 , 0.80132144, 0.80737852])], [array([0.71522251, 0.71378455, 0.73369707, 0.74256747, 0.76157018]), array([0.69490454, 0.69574432, 0.71558598, 0.72313249, 0.74251038]), array([0.74280635, 0.74009438, 0.7659533 , 0.76193099, 0.78325417])], [array([0.65115248, 0.66309737, 0.71571856, 0.72489661, 0.74227466]), array([0.63683262, 0.64875724, 0.69989248, 0.70819183, 0.72072324]), array([0.66628617, 0.67664675, 0.73173818, 0.73919899, 0.75822639])], [array([0.5093237 , 0.65679642, 0.56391302, 0.51458963, 0.5162404 ]), array([0.49094824, 0.59935482, 0.49832324, 0.5       , 0.49950593]), array([0.53208279, 0.68677726, 0.67469795, 0.71884447, 0.74410003])]]
# [13804.38821615 13880.08290365 14000.12188802 13356.31839844
#  12415.11985677]
# [[array([0.84212417, 0.81461746, 0.8084789 , 0.8075982 , 0.82086414]), array([0.83182733, 0.80315564, 0.79249626, 0.79179912, 0.81262324]), array([0.85791902, 0.82817479, 0.82313583, 0.81910474, 0.83090037])], [array([0.78160944, 0.77302748, 0.77415234, 0.77637646, 0.79442757]), array([0.76780434, 0.76074693, 0.75737701, 0.76026006, 0.77905661]), array([0.79143622, 0.78514862, 0.7892385 , 0.80132144, 0.80737852])], [array([0.71522251, 0.71378455, 0.73369707, 0.74256747, 0.76157018]), array([0.69490454, 0.69574432, 0.71558598, 0.72313249, 0.74251038]), array([0.74280635, 0.74009438, 0.7659533 , 0.76193099, 0.78325417])], [array([0.65115248, 0.66309737, 0.71571856, 0.72489661, 0.74227466]), array([0.63683262, 0.64875724, 0.69989248, 0.70819183, 0.72072324]), array([0.66628617, 0.67664675, 0.73173818, 0.73919899, 0.75822639])], [array([0.5093237 , 0.65679642, 0.56391302, 0.51458963, 0.5162404 ]), array([0.49094824, 0.59935482, 0.49832324, 0.5       , 0.49950593]), array([0.53208279, 0.68677726, 0.67469795, 0.71884447, 0.74410003])]]
# [13804.38821615 13880.08290365 14000.12188802 13356.31839844
#  12415.11985677]

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
   
for percent in [5,15,30,50,75]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(15):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/DBLP/incomplete/t=4/edge/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 10))


t = [1,2,3,4,5]
colorli = ['maroon','gold','darkgreen','purple','red']
titleli = ['edge auc','attr auc','edge nll','attr nll']

for k in range(len(plist)):
    print(edge_auc_time)
    print(edge_nll_time[0][0])
  

#edge auc
#平均
   
    axes[0].plot(t, edge_auc_time[k][0], lw=2, label=str(plist[k])+"%欠損", color=colorli[k])
    axes[0].fill_between(t, edge_auc_time[k][1], edge_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション



    axes[1].plot(t, attr_auc_time[k][0], lw=2, label=str(plist[k])+"%欠損", color=colorli[k])
    axes[1].fill_between(t, attr_auc_time[k][1], attr_auc_time[k][2], facecolor=colorli[k], alpha=0.1)  
        #キャプション




        #キャプション

   

    axes[0].set_xticks([1,2,3,4,5])  
    axes[1].set_xticks([1,2,3,4,5])    
 
axes[0].plot(t, edge_mean_baseline[0][:], lw=2, label='欠損なし', color='blue')
axes[0].fill_between(t, edge_max_baseline[0][:], edge_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[1].plot(t, attr_mean_baseline[0][:], lw=2, label='欠損なし', color='blue')
axes[1].fill_between(t, attr_max_baseline[0][:], attr_min_baseline[0][:], facecolor='blue', alpha=0.1)
axes[0].set_xlabel('将来の時刻',fontsize=30)
axes[0].set_ylabel('auc',fontsize=30)

axes[1].set_xlabel('将来の時刻',fontsize=30)
axes[1].set_ylabel('auc',fontsize=30)

axes[1].legend(loc='upper left',fontsize=30,bbox_to_anchor=(1, 1))
axes[0].tick_params(axis="x", labelsize=30)
axes[0].tick_params(axis="y", labelsize=30)
axes[1].tick_params(axis="x", labelsize=30)
axes[1].tick_params(axis="y", labelsize=30)
# Out:
# [[array([0.8759082 , 0.83517049, 0.8290458 , 0.82360428, 0.83876222]), array([0.87578454, 0.8349015 , 0.82825598, 0.82322453, 0.83764356]), array([0.87615017, 0.83549333, 0.82962899, 0.82417242, 0.83931962])], [array([0.87606638, 0.83522416, 0.82925743, 0.82356014, 0.8387519 ]), array([0.8757614 , 0.83498676, 0.82896885, 0.82309236, 0.83804554]), array([0.87636652, 0.83571166, 0.82958729, 0.82423741, 0.83945412])], [array([0.8765178 , 0.8353208 , 0.82937862, 0.8236795 , 0.83877943]), array([0.87596976, 0.83508863, 0.82886479, 0.82334387, 0.83748763]), array([0.87691052, 0.83565941, 0.83005227, 0.82461485, 0.83940396])], [array([0.87689694, 0.83534114, 0.82946208, 0.82373152, 0.83884223]), array([0.8767204 , 0.83511877, 0.82887956, 0.82295137, 0.83820909]), array([0.87717571, 0.83575627, 0.82983903, 0.82416739, 0.83923902])], [array([0.87744183, 0.83544149, 0.82956238, 0.82381283, 0.83918664]), array([0.87694242, 0.83499786, 0.82900314, 0.82316605, 0.83832827]), array([0.87786736, 0.83592565, 0.83003242, 0.82434367, 0.83961801])]]
# [13794.06497396 13868.29906901 13992.01536458 13349.05166016
#  12408.19271484]
# [[array([0.8759082 , 0.83517049, 0.8290458 , 0.82360428, 0.83876222]), array([0.87578454, 0.8349015 , 0.82825598, 0.82322453, 0.83764356]), array([0.87615017, 0.83549333, 0.82962899, 0.82417242, 0.83931962])], [array([0.87606638, 0.83522416, 0.82925743, 0.82356014, 0.8387519 ]), array([0.8757614 , 0.83498676, 0.82896885, 0.82309236, 0.83804554]), array([0.87636652, 0.83571166, 0.82958729, 0.82423741, 0.83945412])], [array([0.8765178 , 0.8353208 , 0.82937862, 0.8236795 , 0.83877943]), array([0.87596976, 0.83508863, 0.82886479, 0.82334387, 0.83748763]), array([0.87691052, 0.83565941, 0.83005227, 0.82461485, 0.83940396])], [array([0.87689694, 0.83534114, 0.82946208, 0.82373152, 0.83884223]), array([0.8767204 , 0.83511877, 0.82887956, 0.82295137, 0.83820909]), array([0.87717571, 0.83575627, 0.82983903, 0.82416739, 0.83923902])], [array([0.87744183, 0.83544149, 0.82956238, 0.82381283, 0.83918664]), array([0.87694242, 0.83499786, 0.82900314, 0.82316605, 0.83832827]), array([0.87786736, 0.83592565, 0.83003242, 0.82434367, 0.83961801])]]
# [[array([0.8759082 , 0.83517049, 0.8290458 , 0.82360428, 0.83876222]), array([0.87578454, 0.8349015 , 0.82825598, 0.82322453, 0.83764356]), array([0.87615017, 0.83549333, 0.82962899, 0.82417242, 0.83931962])], [array([0.87606638, 0.83522416, 0.82925743, 0.82356014, 0.8387519 ]), array([0.8757614 , 0.83498676, 0.82896885, 0.82309236, 0.83804554]), array([0.87636652, 0.83571166, 0.82958729, 0.82423741, 0.83945412])], [array([0.8765178 , 0.8353208 , 0.82937862, 0.8236795 , 0.83877943]), array([0.87596976, 0.83508863, 0.82886479, 0.82334387, 0.83748763]), array([0.87691052, 0.83565941, 0.83005227, 0.82461485, 0.83940396])], [array([0.87689694, 0.83534114, 0.82946208, 0.82373152, 0.83884223]), array([0.8767204 , 0.83511877, 0.82887956, 0.82295137, 0.83820909]), array([0.87717571, 0.83575627, 0.82983903, 0.82416739, 0.83923902])], [array([0.87744183, 0.83544149, 0.82956238, 0.82381283, 0.83918664]), array([0.87694242, 0.83499786, 0.82900314, 0.82316605, 0.83832827]), array([0.87786736, 0.83592565, 0.83003242, 0.82434367, 0.83961801])]]
# [13794.06497396 13868.29906901 13992.01536458 13349.05166016
#  12408.19271484]

# %%
attr_auc_time =[]
attr_nll_time = []
edge_auc_time = []
edge_nll_time = []
   
for percent in [5,15,30,50,75,100]:
    attr_auc = []
    attr_nll = []
    edge_auc = []
    edge_nll = []

    for i in range(15):

        path = "/Users/matsumoto-hirotomo/study/experiment_data/NIPS/incomplete/t=4/edge/percent={}/attempt={}".format(percent,i)
        attr_auc_path = path+"/proposed_attr_auc.npy".format(i)
        attr_nll_path = path+"/proposed_attr_nll.npy".format(i)
        edge_auc_path = path+"/proposed_edge_auc.npy".format(i)
        edge_nll_path = path+"/proposed_edge_nll.npy".format(i)

        attr_auc.append(np.load(attr_auc_path))
        attr_nll.append(np.load(attr_nll_path))
        edge_auc.append(np.load(edge_auc_path))
        edge_nll.append(np.load(edge_nll_path))


    #attr_auc_time.append()
    #attr_nll_time = []
    #edge_auc_time = []
    #edge_nll_time = []
    #ある時刻での欠損の位置を変えた時のそれぞれの値
    time_attr_auc = np.mean(attr_auc,axis=1)
    time_edge_auc = np.mean(edge_auc,axis=1)
    time_attr_nll = np.mean(attr_nll,axis=1)
    time_edge_nll = np.mean(edge_nll,axis=1)

    #auc
    attr_auc_mean = np.mean(time_attr_auc,axis=0)
    attr_auc_max = np.max(time_attr_auc,axis=0)
    attr_auc_min = np.min(time_attr_auc,axis=0)
    edge_auc_mean = np.mean(time_edge_auc,axis=0)
    edge_auc_max = np.max(time_edge_auc,axis=0)
    edge_auc_min = np.min(time_edge_auc,axis=0)

    attr_auc_time.append([attr_auc_mean,attr_auc_min,attr_auc_max])
    edge_auc_time.append([edge_auc_mean,edge_auc_min,edge_auc_max])

    #nll
    attr_nll_mean = np.mean(time_attr_nll,axis=0)
    attr_nll_max = np.max(time_attr_nll,axis=0)
    attr_nll_min = np.min(time_attr_nll,axis=0)
    edge_nll_mean = np.mean(time_edge_nll,axis=0)
    edge_nll_max = np.max(time_edge_nll,axis=0)
    edge_nll_min = np.min(time_edge_nll,axis=0)

    attr_nll_time.append([attr_nll_mean,attr_nll_min,attr_nll_max])
    edge_nll_time.append([edge_nll_mean,edge_nll_min,edge_nll_max])
